# %% [markdown]
# funciones python

# %%
#ejemplo dedfiinicionde dfinciones con python
def suma(numero_1,numero_2):
    resultado = numero_1 + numero_2
    return resultado

# %%
suma(5,10)
# Out:
# 15

# %%
suma(8,4)
# Out:
# 12

# %%
# Usar la funcion y guardar su resultado en una variable externa
resultado_0 = suma(3,6)
resultado_1 = suma(5,10)
resultado_2 = suma(8,4)
print(resultado_0)
print(resultado_1)
print(resultado_2)
# Out:
# 9
# 15
# 12

# %%
#Ejemplo funcones sin parametros y sin retornar
def mensaje():
    print("Este es un mensaje desde la funciones mensajes()")

# %%
mensaje()
# Out:
# Este es un mensaje desde la funciones mensajes()

# %%
def saludo_mensaje

# %%
# Ejemplo definicion de funcion con phyton
